# %% [markdown]
# # Importing the necessary libraries/modules

# %%
import numpy as np
# Importing pandas for Data Visualization....
import pandas as pd
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn import preprocessing
# Importing matplotlib for plotting the graphs...
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %% [markdown]
# # Reading data from file and converting to Pandas DataFrame

# %%
# imported excel sheet is stored in the form of a numpy array....
inc_df = pd.read_excel('C:\\Users\\DELL\\Desktop\\Python Jupyterbook\\Assignment.xlsx')
print(type(inc_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# Coverting the numpy array into Pandas DataFrame....
#inc_df = pd.DataFrame(inc_arr)

# %% [markdown]
# # Exploring the dataset and printing necessary information

# %%
# Printing the no. of observations in our dataset and the parameters/variables that are present in dataset...
print('Total Number of observations are: ',inc_df.shape[0])
print('Total number of parameters(variables) are: ',inc_df.shape[1])
inc_df.head(10)
# Out:
# Total Number of observations are:  48842
# Total number of parameters(variables) are:  15
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital-status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
# Getting an overview of index datatypes and column datatypes of the dataset to be explored...
inc_df.info(memory_usage=False)
# memory_usage = False will not show the memory being consumed after importing the file....
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
# age               48842 non-null int64
# workclass         48842 non-null object
# fnlwgt            48842 non-null int64
# education         48842 non-null object
# education-num     48842 non-null int64
# marital-status    48842 non-null object
# occupation        48842 non-null object
# relationship      48842 non-null object
# race              48842 non-null object
# sex               48842 non-null object
# capital-gain      48842 non-null int64
# capital-loss      48842 non-null int64
# hours-per-week    48842 non-null int64
# native-country    48842 non-null object
# Income            48842 non-null object
# dtypes: int64(6), object(9)

# %%
# Getting a general overview of the dataset about mean, max and min values of the variables....
inc_df.describe()
#sns.countplot(y='education', hue="Income", data=inc_df)
#sns.countplot(y='occupation',hue="Income", data=inc_df)
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  48842.000000  4.884200e+04   48842.000000  48842.000000  48842.000000
# mean      38.643585  1.896641e+05      10.078089   1079.067626     87.502314
# std       13.710510  1.056040e+05       2.570973   7452.019058    403.004552
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.175505e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.781445e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.376420e+05      12.000000      0.000000      0.000000
# max       90.000000  1.490400e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    48842.000000
# mean        40.422382
# std         12.391444
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
# Checking if the given dataset has columns with null values or not....
print('Columns having null values as:\n'+str(inc_df.isnull().sum(axis=0)))
# Or we can check for null values row-wise, whether the given dataset has rows with null values or not....
print('\nRows having null values as:\n'+str(inc_df.isnull().sum(axis=1).head(5)))
# Out:
# Columns having null values as:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# Income            0
# dtype: int64
#
# Rows having null values as:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# dtype: int64

# %%
# We have categorical variables as well as numeric variables
# Since our ML models work on numeric data we have to either convert thid categorical variables into numeric ones or drop them..
# Separating out Categorical variables and numeric variables as follows:
numeric_parameters = inc_df.dtypes[inc_df.dtypes != "object"]
categorical_parameters = inc_df.dtypes[inc_df.dtypes == "object"]
# print(type(categorical_parameters))
print("Categorical variables are:\n"+str(categorical_parameters))
print("\n\nNumeric variables are:\n"+str(numeric_parameters))
# Out:
# Categorical variables are:
# workclass         object
# education         object
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# native-country    object
# Income            object
# dtype: object
#
#
# Numeric variables are:
# age               int64
# fnlwgt            int64
# education-num     int64
# capital-gain      int64
# capital-loss      int64
# hours-per-week    int64
# dtype: object

# %%
# Plotting histograms for the numeric variables and analyzing the distribution of data.....
inc_df[list(numeric_parameters.index)].hist(figsize=(16,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001FE99004128>,
# ...
#       dtype=object)

# %%
print('The different categories in native country along with their counts:\n')
print(inc_df['education'].value_counts())
print('\nThe different categories in native country along with their counts:\n')
print(inc_df['native-country'].value_counts())
print('\nThe different categories in terms of their income with their counts:\n')
print(inc_df['Income'].value_counts())
# Out:
# The different categories in native country along with their counts:
#
#  HS-grad         15784
#  Some-college    10878
#  Bachelors        8025
#  Masters          2657
#  Assoc-voc        2061
#  11th             1812
#  Assoc-acdm       1601
#  10th             1389
#  7th-8th           955
#  Prof-school       834
#  9th               756
#  12th              657
#  Doctorate         594
#  5th-6th           509
#  1st-4th           247
#  Preschool          83
# Name: education, dtype: int64
#
# The different categories in native country along with their counts:
#
#  United-States                 43832
#  Mexico                          951
#  ?                               857
#  Philippines                     295
#  Germany                         206
#  Puerto-Rico                     184
#  Canada                          182
#  El-Salvador                     155
#  India                           151
#  Cuba                            138
# ...

# %%
sns.countplot(inc_df['Income'],label="Count")

# %%
# We will have to restructure the income column since we have to either predict >=50K or less than 50K
inc_df['Income'] = inc_df['Income'].map({"<=50K": 0, ">50K": 1, "<=50K.": 0, ">50K.": 1})
inc_df.head(10)

#inc_df['Income'] = inc_df['Income'].map({'<=50K': 0, '>50K': 1, '<=50K.': 0, '>50K.': 1})
#inc_df.head(10)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital-status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# ...

# %%
#sns.countplot(inc_df['Income'],label="Count")
#inc_df["Income"] = inc_df["Income"].map({"<=50K":0, "<=50K.":0, ">50K":1, ">50K.":1})
#inc_df.head(10)

# %%
# Plotting a heatmap for the correlation matrix
sns.heatmap(inc_df.corr(),cmap="coolwarm",fmt = ".2f",annot=True)

# %%
edit_cols = ['native-country','occupation','workclass']
# Replace ? with unknown
for col in edit_cols:
    inc_df.loc[inc_df[col] == '?', col] = 'unknown'

    
# Check if ? is present
for col in edit_cols:
    print(f"? in {col}:{inc_df[(inc_df[col] == '?')].any().sum()}")
# Out:
# ? in native-country:0
# ? in occupation:0
# ? in workclass:0
#     age          workclass  fnlwgt      education  education-num  \
# 0    39          State-gov   77516      Bachelors             13
# 1    50   Self-emp-not-inc   83311      Bachelors             13
# 2    38            Private  215646        HS-grad              9
# 3    53            Private  234721           11th              7
# 4    28            Private  338409      Bachelors             13
# 5    37            Private  284582        Masters             14
# 6    49            Private  160187            9th              5
# 7    52   Self-emp-not-inc  209642        HS-grad              9
# 8    31            Private   45781        Masters             14
# 9    42            Private  159449      Bachelors             13
# 10   37            Private  280464   Some-college             10
# 11   30          State-gov  141297      Bachelors             13
# ...

# %%
hs_grad = ['HS-grad','11th','10th','9th','12th']
elementary = ['1st-4th','5th-6th','7th-8th']

# replace elements in list.
inc_df['education'].replace(to_replace = hs_grad, value = 'HS-grad', inplace = True)
inc_df['education'].replace(to_replace = elementary, value = 'elementary_school', inplace = True)
inc_df['education'].value_counts()
          
#inc_df.head(20)
# Out:
#  HS-grad         15784
#  Some-college    10878
#  Bachelors        8025
#  Masters          2657
#  Assoc-voc        2061
#  11th             1812
#  Assoc-acdm       1601
#  10th             1389
#  7th-8th           955
#  Prof-school       834
#  9th               756
#  12th              657
#  Doctorate         594
#  5th-6th           509
#  1st-4th           247
#  Preschool          83
# Name: education, dtype: int64

# %%
married= ['Married-spouse-absent','Married-civ-spouse','Married-AF-spouse']
separated = ['Separated','Divorced']
#print(inc_df['marital-status'].value_counts())
print(type(married))

#replace elements in list.
inc_df = inc_df.replace(to_replace = married, value = 'Married')
inc_df = inc_df.replace(to_replace = separated, value = 'Separated')

inc['marital-status'].value_counts()
# Out:
# <class 'list'>
#  Married-civ-spouse       22379
#  Never-married            16117
#  Divorced                  6633
#  Separated                 1530
#  Widowed                   1518
#  Married-spouse-absent      628
#  Married-AF-spouse           37
# Name: marital-status, dtype: int64
